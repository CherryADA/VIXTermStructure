# %% [markdown]
# # PCA Analysis on VIX term structure
# We will extract a smaller number of factors that can capture the movement of the term structure. We propose to use three methods for this analysis including traditional PCA over entire window, rolloiing window traditional PCA and rolling window exponential weighted PCA.
#
# ### Load files

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
dfs = pd.read_excel("09.9.21_ux1-8.xlsx", sheet_name="data")
col=dfs.columns.tolist()
col.remove('VIX.Index')
col.insert(1,'VIX.Index')
dfs=dfs.reindex(columns= col)
dfs.head()
# Out:
#         Date  VIX.Index  UX1..index  UX2..index  UX3..index  UX4..index  \
# 0 2009-09-21      24.06       26.70       28.40       28.05       28.65
# 1 2009-09-22      23.08       26.10       28.05       27.80       28.55
# 2 2009-09-23      23.49       26.35       28.15       27.85       28.30
# 3 2009-09-24      24.95       26.90       28.50       28.35       28.80
# 4 2009-09-25      25.61       27.00       28.55       28.35       28.85
#
#    UX5..index  UX6..index  UX7..index  UX8..index  slope(UX8-UX1)  \
# 0       28.70       28.60       28.70       28.70            2.00
# 1       28.75       28.60       28.90       28.50            2.40
# 2       28.60       28.45       28.65       28.60            2.25
# 3       29.15       29.10       29.35       28.65            1.75
# 4       29.25       29.20       29.50       29.40            2.40
#
#    curvature(8+2-2*5)  curvature(1+8-2*5)  slope(UX5-UX1)
# 0               -0.30               -2.00            2.00
# 1               -0.95               -2.90            2.65
# 2               -0.45               -2.25            2.25
# 3               -1.15               -2.75            2.25
# 4               -0.55               -2.10            2.25

# %%
df_commodity = pd.read_csv("commodity.csv",index_col=0)
df_equtiy = pd.read_csv("equity.csv", index_col=0)
df_fixedIncome = pd.read_csv("fixed_income.csv",index_col=0)
df_fx = pd.read_csv("fx.csv",index_col=0)
df_commodity["Date"] = df_commodity["Date"].apply(lambda x: datetime.strptime(x , "%Y-%m-%d"))
df_equtiy["Date"] = df_equtiy["Date"].apply(lambda x: datetime.strptime(x , "%Y-%m-%d"))
df_fixedIncome["Date"] = df_fixedIncome["Date"].apply(lambda x: datetime.strptime(x , "%Y-%m-%d"))
df_fx["Date"] = df_fx["Date"].apply(lambda x: datetime.strptime(x , "%Y-%m-%d"))

df_commodity.name = 'commodity'
df_equtiy.name = 'equtiy'
df_fixedIncome.name = 'fixedIncome'
df_fx.name = 'fx'

# %% [markdown]
# ## Fill Missing Data

# %% [markdown]
# Check if the dataframe contains NaN:

# %%
dfs.isna().sum().sum()
# Out:
# 1

# %%
dfs.columns[dfs.isna().any()]
# Out:
# Index(['VIX.Index'], dtype='object')

# %% [markdown]
# One vix index is NaN, we will fill the missing value by forward filling, which is filled by the previous date's data.

# %%
dfs = dfs.fillna(method='ffill')
dfs.isna().sum().sum()
# Out:
# 0

# %%
## fill missing data in pontential factor files as well
df_commodity = df_commodity.fillna(method='ffill')
df_equtiy = df_equtiy.fillna(method='ffill')
df_fixedIncome = df_fixedIncome.fillna(method='ffill')
df_fx = df_fx.fillna(method='ffill')

# %% [markdown]
# ## Term Structure Snapshot

# %%
import matplotlib.pyplot as plt
listTermStructureColumn = ["VIX.Index",'UX1..index', 'UX2..index', 'UX3..index', 'UX4..index',
       'UX5..index', 'UX6..index', 'UX7..index', 'UX8..index']
def getTermStruturePlot(df, date):
    dfs[dfs['Date'] == date]
    plt.plot(np.array([n for n in range(9)]), np.array(dfs[dfs['Date'] == date][listTermStructureColumn]).flatten())

# %%
date = datetime(2009, 9, 21)
getTermStruturePlot(dfs, date)

# %%
date = datetime(2018, 9, 21)
getTermStruturePlot(dfs, date)

# %% [markdown]
# Let's take a look on the data distribution of the term structure with only 3 futures prices

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x, y, z =  dfs[listTermStructureColumn[0]], dfs[listTermStructureColumn[1]], dfs[listTermStructureColumn[2]]
ax.scatter(x, y, z, label='3 period forward vix term structure')
ax.legend()
plt.show()

# %% [markdown]
# From the graph above, one can feel is that the term structure lies on a 2-d surface, which suggests us to consider the PCA analysis.

# %% [markdown]
# Load factors in each asset classes for future usage.

# %%
#df_factor = pd.merge(df_commodity, df_equtiy, right_index=True, left_index=True, on="Date")
#df_factor = pd.merge(df_factor, df_fixedIncome, right_index=True, left_index=True, on="Date")
#df_factor = pd.merge(df_factor, df_fx, right_index=True, left_index=True, on="Date")
#df_factor = df_factor.dropna()
#df_factor.head()

df_factor = pd.merge(df_commodity, df_equtiy, how='inner',on="Date")
df_factor = pd.merge(df_factor, df_fixedIncome, how='inner', on="Date")
df_factor = pd.merge(df_factor, df_fx, how='inner', on="Date")
df_factor = df_factor.dropna()
df_all = pd.merge(df_factor,dfs, how='inner',on="Date")
df_all = df_all.dropna()
df_all.tail()
# Out:
#            Date  CL1.Comdty_x  CL1.Comdty_y  XAU.Curncy  RTY.Index_x  \
# 2432 2019-05-20         63.10         63.10     1277.82      1524.96
# 2433 2019-05-21         62.99         62.99     1274.68      1545.25
# 2434 2019-05-22         61.42         61.42     1273.34      1531.63
# 2435 2019-05-23         57.91         57.91     1283.45      1501.38
# 2436 2019-05-24         58.63         58.63     1284.93      1514.11
#
#       RTY.Index_y  MXEA.Index  LEGATRUU.Index_x  LEGATRUU.Index_y  \
# 2432      1524.96     1858.28            489.45            489.45
# 2433      1545.25     1861.58            488.94            488.94
# 2434      1531.63     1857.58            489.22            489.22
# 2435      1501.38     1839.56            490.95            490.95
# 2436      1514.11     1853.26            491.90            491.90
#
#       LF98TRUU.Index  ...  UX3..index  UX4..index  UX5..index  UX6..index  \
# 2432         2066.42  ...      17.425      17.475      17.575      17.625
# 2433         2068.22  ...      16.725      16.975      17.225      17.300
# 2434         2067.91  ...      16.875      17.075      17.225      17.325
# 2435         2062.80  ...      17.675      17.725      17.775      17.775
# 2436         2063.41  ...      17.425      17.625      17.675      17.725
#
#       UX7..index  UX8..index  slope(UX8-UX1)  curvature(8+2-2*5)  \
# 2432      17.625      17.350           1.225              -0.625
# 2433      17.325      17.100           2.075              -1.075
# 2434      17.375      17.200           2.190              -1.025
# 2435      17.525      18.050           0.725               0.125
# 2436      17.450      17.975           1.250              -0.050
#
#       curvature(1+8-2*5)  slope(UX5-UX1)
# 2432              -1.675           1.450
# 2433              -2.325           2.200
# 2434              -2.240           2.215
# 2435              -0.175           0.450
# 2436              -0.650           0.950
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Traditional PCA
# Here we are trying to get a smaller term in vix term structure which can explain the term structure.

# %% [markdown]
# Import backend PCA utility functions.

# %%
from PCA_UtilityFunc import rollingPCA, weightedPCA, dfPCA, logreturns, expweight, df_merge, clean_df
import math
from sklearn.decomposition import PCA

# %%
n = 4 #number of compoents for PCA
index = ['PC1', 'PC2', "PC3", "PC4"]
#index = ['PC1', 'PC2', "PC3"]
pca = PCA(n_components=n)
principalComponents = pca.fit(dfs.drop('Date', axis = 1)[listTermStructureColumn])
pca_result = pd.DataFrame(principalComponents.explained_variance_ratio_, index = index, columns=["eigenvalues"])
pca_result
# Out:
#      eigenvalues
# PC1     0.931699
# PC2     0.061547
# PC3     0.004241
# PC4     0.001512

# %%
principalComponents.explained_variance_
# Out:
# array([207.69413729,  13.72015774,   0.9454942 ,   0.33704877])

# %%
principalComponents.explained_variance_
# Out:
# array([207.69413729,  13.72015774,   0.9454942 ,   0.33704877])

# %% [markdown]
# Eigenvectors (the directions which have most variance)

# %%
eigenVectors = pd.DataFrame(principalComponents.components_, index = ['PC1', 'PC2', "PC3", "PC4"])
eigenVectors
# Out:
#             0         1         2         3         4         5         6  \
# PC1  0.360137  0.348097  0.344398  0.338348  0.331572  0.327557  0.321595
# PC2  0.673057  0.426736  0.106978 -0.053495 -0.150681 -0.221291 -0.270992
# PC3  0.540547 -0.266851 -0.474032 -0.344236 -0.206463 -0.034671  0.151528
# PC4 -0.352229  0.738954 -0.107912 -0.308842 -0.285486 -0.154061  0.032035
#
#             7         8
# PC1  0.316613  0.308446
# PC2 -0.307499 -0.333044
# PC3  0.300667  0.369059
# PC4  0.176996  0.291997

# %%
a = dfs.drop('Date', axis = 1)[listTermStructureColumn]
decomp_set = pd.DataFrame(np.dot(a, eigenVectors.T), columns=["PC1", "PC2", "PC3", "PC4"])
decomp_set.index =  dfs.Date
decomp_set.plot()

# %% [markdown]
# ## Rolling Window Tranditional PCA

# %%
ws = 120
n = 4 #number of compoents for PCA
eigenvalues = [[] for i in range(n)]
eigenvalues_value = [[] for i in range(n)]
eigenvectors = {}
newdf = dfs.drop('Date', axis = 1)[listTermStructureColumn]
i=0
pca_dates = []
while (i+ws) <= len(newdf):
    pca_dates.append(df_all.iloc[i+ws-1,0])
    subdf = newdf.iloc[i:(i+ws),:]
    pca = PCA(n_components=n)
    principalComponents = pca.fit(subdf[listTermStructureColumn])
    results = principalComponents.explained_variance_ratio_
    results_value = principalComponents.explained_variance_
    eigenvectors[pca_dates[i]] = principalComponents.components_
    for j in range(n):
        eigenvalues[j].append(float(results[j]))
        eigenvalues_value[j].append(float(results_value[j]))
    i+=1
 
    
eigenvalues_ratios = pd.DataFrame(data = eigenvalues).T
eigenvalues_values = pd.DataFrame(data = eigenvalues_value).T

eigenvalues_ratios.plot(figsize=(20,7))
eigenvalues_values.plot(figsize=(20,7))

# %%
#Put dates as column in eigenvalues
len(pca_dates)==len(eigenvalues_ratios)
eigenvalues_ratios.insert(loc=0,column='Date', value=pca_dates)
eigenvalues_ratios.tail()
# Out:
#            Date         0         1         2         3
# 2313 2019-05-20  0.969353  0.023253  0.005639  0.001257
# 2314 2019-05-21  0.969520  0.023118  0.005588  0.001273
# 2315 2019-05-22  0.969623  0.023028  0.005552  0.001294
# 2316 2019-05-23  0.969631  0.022999  0.005550  0.001292
# 2317 2019-05-24  0.969651  0.022986  0.005523  0.001292

# %%
eigenvalues_ratios.head()
# Out:
#         Date         0         1         2         3
# 0 2010-03-12  0.859063  0.120678  0.013653  0.003421
# 1 2010-03-15  0.861276  0.119021  0.013195  0.003378
# 2 2010-03-16  0.864749  0.116072  0.012839  0.003312
# 3 2010-03-17  0.866977  0.114314  0.012363  0.003354
# 4 2010-03-18  0.868151  0.113287  0.012219  0.003439

# %%
temp= pd.DataFrame(eigenvectors[pca_dates[20]])
print(temp)

plt.plot(temp.iloc[0,:])
plt.plot(temp.iloc[1,:])
plt.plot(temp.iloc[2,:])

plt.legend()
plt.xlabel('Maturity')
plt.ylabel('Eigenvector Coordinates')
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.471415  0.397011  0.345748  0.330701  0.306207  0.293051  0.280597
# 1  0.659413  0.380845 -0.046329 -0.191443 -0.242787 -0.281596 -0.266275
# 2 -0.571954  0.669274  0.388953  0.063922 -0.045135 -0.114872 -0.162840
# 3  0.096348 -0.477580  0.663522  0.360900 -0.033072  0.011930 -0.241677
#
#           7         8
# 0  0.259226  0.256263
# 1 -0.283711 -0.302819
# 2 -0.145956 -0.080729
# 3 -0.204037 -0.301411
# Text(0, 0.5, 'Eigenvector Coordinates')

# %%
dfs['Date']= pd.to_datetime(dfs['Date'])
dfs.info() 
dfs= dfs.set_index('Date')
pca_dates[20]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-22b8a4780756> in <module>
# ----> 1 dfs['Date']= pd.to_datetime(dfs['Date'])
#       2 dfs.info()
#       3 dfs= dfs.set_index('Date')
#       4 pd.Timestamp.pca_dates[20]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'

# %% [markdown]
# ## Distrubution Of Eigenvalues

# %%
plt.bar([x for x in range(15)], dfPCA(logreturns(df_factor.drop('Date', axis = 1)), 15))
plt.title("First 15th Components' Eigenvalue")
# Out:
# Text(0.5, 1.0, "First 15th Components' Eigenvalue")

# %%
eigenvalues_ratios.iloc[:,1].plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('PC0')
plt.xlabel(' Variance Explained Ratio')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()


eigenvalues_ratios.iloc[:,2].plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('PC1')
plt.xlabel(' Variance Explained Ratio')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

eigenvalues_ratios.iloc[:,3].plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('PC2')
plt.xlabel(' Variance Explained Ratio')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

eigenvalues_ratios.iloc[:,4].plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('PC3')
plt.xlabel(' Variance Explained Ratio')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)


plt.show()

# %%
#Compare the histogram of PC2,PC3,PC4


plt.hist(eigenvalues_ratios.iloc[:,2], bins=20, rwidth=0.9
                   ,  label='PC1')

plt.hist(eigenvalues_ratios.iloc[:,3], bins=20, rwidth=0.9
                   ,  label='PC2')
plt.hist(eigenvalues_ratios.iloc[:,4], bins=20, rwidth=0.9
                   , label='PC3')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Correlation With Other Assets

# %%
#truncate assets data so that it has the same length with vix data
#df_commodity['Date']=pd.to_datetime(df_commodity['Date'])
#df_commodity.set_index('Date', inplace=True) 
#df_commodity.head()
#firstday= pd.to_datetime(dfs.iloc[ws+1,0])
#lastday= pd.to_datetime(dfs.iloc[-1,0])
#df_commodity_truncated = df_commodity.loc[firstday:lastday, :]
#df_commodity_truncated.tail()
#type(dfs.iloc[0,0])
#Use eigenvector as coefficients of linear combiniation of VIX futures
#Rescale eigenvector

# %%
df_pca_and_assets=pd.merge(df_all, eigenvalues_ratios, how='inner', on="Date")
df_pca_and_assets.head()
df_pca_and_assets.corr()
# Out:
#                     CL1.Comdty_x  CL1.Comdty_y  XAU.Curncy  RTY.Index_x  \
# CL1.Comdty_x            1.000000      1.000000    0.590692    -0.542423
# CL1.Comdty_y            1.000000      1.000000    0.590692    -0.542423
# XAU.Curncy              0.590692      0.590692    1.000000    -0.525822
# RTY.Index_x            -0.542423     -0.542423   -0.525822     1.000000
# RTY.Index_y            -0.542423     -0.542423   -0.525822     1.000000
# MXEA.Index             -0.217637     -0.217637   -0.496096     0.827194
# LEGATRUU.Index_x       -0.278886     -0.278886    0.023431     0.724719
# LEGATRUU.Index_y       -0.278886     -0.278886    0.023431     0.724719
# LF98TRUU.Index         -0.548463     -0.548463   -0.439332     0.973390
# LGTRTRUU.Index          0.024336      0.024336    0.407770     0.377101
# LUACTRUU.Index         -0.648463     -0.648463   -0.393569     0.918525
# LUATTRUU.Index         -0.671088     -0.671088   -0.278686     0.792771
# USDJPY.Curncy_x        -0.722522     -0.722522   -0.808824     0.788852
# USDJPY.Curncy_y        -0.722522     -0.722522   -0.808824     0.788852
# USDEUR.Curncy          -0.896257     -0.896257   -0.566984     0.622982
# VIX.Index               0.116033      0.116033    0.294550    -0.538867
# UX1..index              0.145482      0.145482    0.327700    -0.603815
# UX2..index              0.198131      0.198131    0.356185    -0.697033
# UX3..index              0.242380      0.242380    0.388531    -0.751171
# UX4..index              0.270721      0.270721    0.406738    -0.780950
# UX5..index              0.298917      0.298917    0.441485    -0.803373
# UX6..index              0.325001      0.325001    0.471833    -0.823352
# UX7..index              0.344004      0.344004    0.495163    -0.836815
# UX8..index              0.352348      0.352348    0.505816    -0.843020
# slope(UX8-UX1)          0.284165      0.284165    0.200618    -0.233793
# curvature(8+2-2*5)     -0.218097     -0.218097   -0.085565     0.268417
# curvature(1+8-2*5)     -0.197604     -0.197604   -0.051329     0.238246
# slope(UX5-UX1)          0.254718      0.254718    0.141707    -0.242280
# 0                      -0.077646     -0.077646    0.017695    -0.021917
# 1                       0.119619      0.119619   -0.004656    -0.040731
# 2                      -0.068261     -0.068261   -0.127398     0.249308
# 3                      -0.068532     -0.068532    0.024508     0.152918
#
#                     RTY.Index_y  MXEA.Index  LEGATRUU.Index_x  \
# CL1.Comdty_x          -0.542423   -0.217637         -0.278886
# CL1.Comdty_y          -0.542423   -0.217637         -0.278886
# XAU.Curncy            -0.525822   -0.496096          0.023431
# RTY.Index_x            1.000000    0.827194          0.724719
# RTY.Index_y            1.000000    0.827194          0.724719
# MXEA.Index             0.827194    1.000000          0.573048
# LEGATRUU.Index_x       0.724719    0.573048          1.000000
# LEGATRUU.Index_y       0.724719    0.573048          1.000000
# LF98TRUU.Index         0.973390    0.771603          0.819421
# LGTRTRUU.Index         0.377101    0.271277          0.893881
# LUACTRUU.Index         0.918525    0.663286          0.852211
# LUATTRUU.Index         0.792771    0.477065          0.843405
# USDJPY.Curncy_x        0.788852    0.669733          0.384013
# USDJPY.Curncy_y        0.788852    0.669733          0.384013
# USDEUR.Curncy          0.622982    0.228921          0.315631
# VIX.Index             -0.538867   -0.628263         -0.427265
# UX1..index            -0.603815   -0.694188         -0.481638
# UX2..index            -0.697033   -0.778844         -0.574714
# UX3..index            -0.751171   -0.817961         -0.619337
# UX4..index            -0.780950   -0.838202         -0.641859
# UX5..index            -0.803373   -0.852198         -0.646032
# UX6..index            -0.823352   -0.862532         -0.646624
# UX7..index            -0.836815   -0.870729         -0.646018
# UX8..index            -0.843020   -0.874997         -0.646826
# slope(UX8-UX1)        -0.233793   -0.124972         -0.147379
# curvature(8+2-2*5)     0.268417    0.183331          0.286885
# curvature(1+8-2*5)     0.238246    0.164221          0.266409
# slope(UX5-UX1)        -0.242280   -0.145448         -0.202976
# 0                     -0.021917   -0.208182          0.000588
# 1                     -0.040731    0.150638         -0.058462
# 2                      0.249308    0.385454          0.180366
# 3                      0.152918    0.229511          0.155539
#
#                     LEGATRUU.Index_y  LF98TRUU.Index  LGTRTRUU.Index  ...  \
# CL1.Comdty_x               -0.278886       -0.548463        0.024336  ...
# CL1.Comdty_y               -0.278886       -0.548463        0.024336  ...
# XAU.Curncy                  0.023431       -0.439332        0.407770  ...
# RTY.Index_x                 0.724719        0.973390        0.377101  ...
# RTY.Index_y                 0.724719        0.973390        0.377101  ...
# MXEA.Index                  0.573048        0.771603        0.271277  ...
# LEGATRUU.Index_x            1.000000        0.819421        0.893881  ...
# LEGATRUU.Index_y            1.000000        0.819421        0.893881  ...
# LF98TRUU.Index              0.819421        1.000000        0.494557  ...
# LGTRTRUU.Index              0.893881        0.494557        1.000000  ...
# LUACTRUU.Index              0.852211        0.971890        0.545819  ...
# LUATTRUU.Index              0.843405        0.876383        0.588067  ...
# USDJPY.Curncy_x             0.384013        0.757561       -0.056993  ...
# USDJPY.Curncy_y             0.384013        0.757561       -0.056993  ...
# USDEUR.Curncy               0.315631        0.639482       -0.017789  ...
# VIX.Index                  -0.427265       -0.547515       -0.220148  ...
# UX1..index                 -0.481638       -0.616125       -0.247656  ...
# UX2..index                 -0.574714       -0.713098       -0.306184  ...
# UX3..index                 -0.619337       -0.767537       -0.327789  ...
# UX4..index                 -0.641859       -0.796523       -0.337378  ...
# UX5..index                 -0.646032       -0.815454       -0.328048  ...
# UX6..index                 -0.646624       -0.831521       -0.316211  ...
# UX7..index                 -0.646018       -0.841922       -0.307200  ...
# UX8..index                 -0.646826       -0.846220       -0.304575  ...
# slope(UX8-UX1)             -0.147379       -0.217206       -0.033003  ...
# curvature(8+2-2*5)          0.286885        0.288159        0.183884  ...
# curvature(1+8-2*5)          0.266409        0.254006        0.178095  ...
# slope(UX5-UX1)             -0.202976       -0.239212       -0.096657  ...
# 0                           0.000588       -0.040148        0.034105  ...
# 1                          -0.058462       -0.024358       -0.077723  ...
# 2                           0.180366        0.262849        0.078566  ...
# 3                           0.155539        0.181439        0.116766  ...
#
#                     UX7..index  UX8..index  slope(UX8-UX1)  \
# CL1.Comdty_x          0.344004    0.352348        0.284165
# CL1.Comdty_y          0.344004    0.352348        0.284165
# XAU.Curncy            0.495163    0.505816        0.200618
# RTY.Index_x          -0.836815   -0.843020       -0.233793
# RTY.Index_y          -0.836815   -0.843020       -0.233793
# MXEA.Index           -0.870729   -0.874997       -0.124972
# LEGATRUU.Index_x     -0.646018   -0.646826       -0.147379
# LEGATRUU.Index_y     -0.646018   -0.646826       -0.147379
# LF98TRUU.Index       -0.841922   -0.846220       -0.217206
# LGTRTRUU.Index       -0.307200   -0.304575       -0.033003
# LUACTRUU.Index       -0.784210   -0.788383       -0.217543
# LUATTRUU.Index       -0.655166   -0.658623       -0.214576
# USDJPY.Curncy_x      -0.759292   -0.769304       -0.307369
# USDJPY.Curncy_y      -0.759292   -0.769304       -0.307369
# USDEUR.Curncy        -0.423475   -0.428466       -0.154749
# VIX.Index             0.758956    0.741037       -0.565674
# UX1..index            0.836885    0.821141       -0.490690
# UX2..index            0.930523    0.918563       -0.287060
# UX3..index            0.966844    0.957822       -0.163558
# UX4..index            0.983127    0.976564       -0.082983
# UX5..index            0.992660    0.987960       -0.021208
# UX6..index            0.997666    0.994761        0.027067
# UX7..index            1.000000    0.997903        0.063703
# UX8..index            0.997903    1.000000        0.094368
# slope(UX8-UX1)        0.063703    0.094368        1.000000
# curvature(8+2-2*5)   -0.197858   -0.202389       -0.748177
# curvature(1+8-2*5)   -0.168158   -0.181328       -0.889497
# slope(UX5-UX1)        0.110650    0.134612        0.980293
# 0                     0.231145    0.214725       -0.279571
# 1                    -0.182789   -0.167782        0.253415
# 2                    -0.383981   -0.371175        0.227760
# 3                    -0.238010   -0.219279        0.301588
#
#                     curvature(8+2-2*5)  curvature(1+8-2*5)  slope(UX5-UX1)  \
# CL1.Comdty_x                 -0.218097           -0.197604        0.254718
# CL1.Comdty_y                 -0.218097           -0.197604        0.254718
# XAU.Curncy                   -0.085565           -0.051329        0.141707
# RTY.Index_x                   0.268417            0.238246       -0.242280
# RTY.Index_y                   0.268417            0.238246       -0.242280
# MXEA.Index                    0.183331            0.164221       -0.145448
# LEGATRUU.Index_x              0.286885            0.266409       -0.202976
# LEGATRUU.Index_y              0.286885            0.266409       -0.202976
# LF98TRUU.Index                0.288159            0.254006       -0.239212
# LGTRTRUU.Index                0.183884            0.178095       -0.096657
# LUACTRUU.Index                0.300184            0.260680       -0.242298
# LUATTRUU.Index                0.304337            0.264437       -0.242155
# USDJPY.Curncy_x               0.279728            0.252047       -0.292079
# USDJPY.Curncy_y               0.279728            0.252047       -0.292079
# USDEUR.Curncy                 0.140817            0.092656       -0.132248
# VIX.Index                     0.326804            0.439204       -0.526874
# UX1..index                    0.251779            0.351228       -0.444168
# UX2..index                    0.075881            0.121891       -0.223709
# UX3..index                   -0.040170            0.003049       -0.098756
# UX4..index                   -0.112467           -0.070082       -0.019137
# UX5..index                   -0.168955           -0.124629        0.041247
# UX6..index                   -0.182928           -0.148967        0.080527
# UX7..index                   -0.197858           -0.168158        0.110650
# UX8..index                   -0.202389           -0.181328        0.134612
# slope(UX8-UX1)               -0.748177           -0.889497        0.980293
# curvature(8+2-2*5)            1.000000            0.907726       -0.838154
# curvature(1+8-2*5)            0.907726            1.000000       -0.962236
# slope(UX5-UX1)               -0.838154           -0.962236        1.000000
# 0                             0.146202            0.149880       -0.231349
# 1                            -0.139492           -0.138317        0.210768
# 2                            -0.100388           -0.112860        0.184478
# 3                            -0.097482           -0.131487        0.236513
#
#                            0         1         2         3
# CL1.Comdty_x       -0.077646  0.119619 -0.068261 -0.068532
# CL1.Comdty_y       -0.077646  0.119619 -0.068261 -0.068532
# XAU.Curncy          0.017695 -0.004656 -0.127398  0.024508
# RTY.Index_x        -0.021917 -0.040731  0.249308  0.152918
# RTY.Index_y        -0.021917 -0.040731  0.249308  0.152918
# MXEA.Index         -0.208182  0.150638  0.385454  0.229511
# LEGATRUU.Index_x    0.000588 -0.058462  0.180366  0.155539
# LEGATRUU.Index_y    0.000588 -0.058462  0.180366  0.155539
# LF98TRUU.Index     -0.040148 -0.024358  0.262849  0.181439
# LGTRTRUU.Index      0.034105 -0.077723  0.078566  0.116766
# LUACTRUU.Index      0.000710 -0.063739  0.218642  0.159654
# LUATTRUU.Index      0.066117 -0.113592  0.116490  0.082447
# USDJPY.Curncy_x    -0.002065 -0.022781  0.159754  0.006445
# USDJPY.Curncy_y    -0.002065 -0.022781  0.159754  0.006445
# USDEUR.Curncy       0.122515 -0.154373  0.037969  0.008481
# VIX.Index           0.340136 -0.288308 -0.432649 -0.347087
# UX1..index          0.348210 -0.292128 -0.455439 -0.364818
# UX2..index          0.337290 -0.280907 -0.459105 -0.353028
# UX3..index          0.312318 -0.257422 -0.445301 -0.326883
# UX4..index          0.284807 -0.231587 -0.425347 -0.300887
# UX5..index          0.264184 -0.212685 -0.408915 -0.279934
# UX6..index          0.245267 -0.195035 -0.395963 -0.259403
# UX7..index          0.231145 -0.182789 -0.383981 -0.238010
# UX8..index          0.214725 -0.167782 -0.371175 -0.219279
# slope(UX8-UX1)     -0.279571  0.253415  0.227760  0.301588
# curvature(8+2-2*5)  0.146202 -0.139492 -0.100388 -0.097482
# curvature(1+8-2*5)  0.149880 -0.138317 -0.112860 -0.131487
# slope(UX5-UX1)     -0.231349  0.210768  0.184478  0.236513
# 0                   1.000000 -0.978720 -0.784438 -0.663756
# 1                  -0.978720  1.000000  0.656041  0.516710
# 2                  -0.784438  0.656041  1.000000  0.794332
# 3                  -0.663756  0.516710  0.794332  1.000000
#
# [32 rows x 32 columns]

# %%
len(eigenvectors.keys())
# Out:
# 2318

# %%
i
# Out:
# 2318
